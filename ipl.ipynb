# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r'C:\Users\Sahil Vimal\Desktop\ipl-matches.csv')
df
# Out:
#           ID        City       Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  5/29/2022     2022        Final
# 1    1312199   Ahmedabad  5/27/2022     2022  Qualifier 2
# 2    1312198     Kolkata  5/25/2022     2022   Eliminator
# 3    1312197     Kolkata  5/24/2022     2022  Qualifier 1
# 4    1304116      Mumbai  5/22/2022     2022           70
# ..       ...         ...        ...      ...          ...
# 945   335986     Kolkata  4/20/2008  2007/08            4
# 946   335985      Mumbai  4/20/2008  2007/08            5
# 947   335984       Delhi  4/19/2008  2007/08            3
# 948   335983  Chandigarh  4/19/2008  2007/08            2
# 949   335982   Bangalore  4/18/2008  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
df.dtypes
# Out:
# ID                   int64
# City                object
# Date                object
# Season              object
# MatchNumber         object
# Team1               object
# Team2               object
# Venue               object
# TossWinner          object
# TossDecision        object
# SuperOver           object
# WinningTeam         object
# WonBy               object
# Margin             float64
# method              object
# Player_of_Match     object
# Team1Players        object
# Team2Players        object
# Umpire1             object
# Umpire2             object
# dtype: object

# %%
df.index
# Out:
# RangeIndex(start=0, stop=950, step=1)

# %%
df.columns
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2'],
#       dtype='object')

# %%
df.head()
# Out:
#         ID       City       Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  5/29/2022   2022        Final
# 1  1312199  Ahmedabad  5/27/2022   2022  Qualifier 2
# 2  1312198    Kolkata  5/25/2022   2022   Eliminator
# 3  1312197    Kolkata  5/24/2022   2022  Qualifier 1
# 4  1304116     Mumbai  5/22/2022   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
df.tail()
# Out:
#          ID        City       Date   Season MatchNumber  \
# 945  335986     Kolkata  4/20/2008  2007/08           4
# 946  335985      Mumbai  4/20/2008  2007/08           5
# 947  335984       Delhi  4/19/2008  2007/08           3
# 948  335983  Chandigarh  4/19/2008  2007/08           2
# 949  335982   Bangalore  4/18/2008  2007/08           1
#
#                            Team1                        Team2  \
# 945        Kolkata Knight Riders              Deccan Chargers
# 946               Mumbai Indians  Royal Challengers Bangalore
# 947             Delhi Daredevils             Rajasthan Royals
# 948              Kings XI Punjab          Chennai Super Kings
# 949  Royal Challengers Bangalore        Kolkata Knight Riders
#
#                                           Venue                   TossWinner  \
# 945                                Eden Gardens              Deccan Chargers
# 946                            Wankhede Stadium               Mumbai Indians
# ...

# %%
#sample key word gives us random rows from data
df.sample(5)
# Out:
#           ID     City       Date Season MatchNumber                  Team1  \
# 129  1254062  Chennai  4/13/2021   2021           5         Mumbai Indians
# 579   598046   Mumbai   5/5/2013   2013          49         Mumbai Indians
# 363  1082600   Mumbai  4/12/2017   2017          10         Mumbai Indians
# 728   501245  Kolkata   5/7/2011   2011          48  Kolkata Knight Riders
# 589   598034  Chennai  4/28/2013   2013          38    Chennai Super Kings
#
#                      Team2                                     Venue  \
# 129  Kolkata Knight Riders  MA Chidambaram Stadium, Chepauk, Chennai
# 579    Chennai Super Kings                          Wankhede Stadium
# 363    Sunrisers Hyderabad                          Wankhede Stadium
# 728    Chennai Super Kings                              Eden Gardens
# 589  Kolkata Knight Riders           MA Chidambaram Stadium, Chepauk
#
#                 TossWinner TossDecision SuperOver            WinningTeam  \
# ...

# %%
df.values
# Out:
# array([[1312200, 'Ahmedabad', '5/29/2022', ...,
#         "['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pandya', 'DA Miller', 'R Tewatia', 'Rashid Khan', 'R Sai Kishore', 'LH Ferguson', 'Yash Dayal', 'Mohammed Shami']",
#         'CB Gaffaney', 'Nitin Menon'],
#        [1312199, 'Ahmedabad', '5/27/2022', ...,
#         "['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D Padikkal', 'SO Hetmyer', 'R Parag', 'R Ashwin', 'TA Boult', 'YS Chahal', 'M Prasidh Krishna', 'OC McCoy']",
#         'CB Gaffaney', 'Nitin Menon'],
#        [1312198, 'Kolkata', '5/25/2022', ...,
#         "['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda', 'MP Stoinis', 'E Lewis', 'KH Pandya', 'PVD Chameera', 'Mohsin Khan', 'Avesh Khan', 'Ravi Bishnoi']",
#         'J Madanagopal', 'MA Gough'],
#        ...,
#        [335984, 'Delhi', '4/19/2008', ...,
#         "['T Kohli', 'YK Pathan', 'SR Watson', 'M Kaif', 'DS Lehmann', 'RA Jadeja', 'M Rawat', 'D Salunkhe', 'SK Warne', 'SK Trivedi', 'MM Patel']",
# ...

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 945    False
# 946    False
# 947    False
# 948    False
# 949    False
# Length: 950, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (950, 20)

# %%
df.head(5)
# Out:
#         ID       City       Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  5/29/2022   2022        Final
# 1  1312199  Ahmedabad  5/27/2022   2022  Qualifier 2
# 2  1312198    Kolkata  5/25/2022   2022   Eliminator
# 3  1312197    Kolkata  5/24/2022   2022  Qualifier 1
# 4  1304116     Mumbai  5/22/2022   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
#season winning team

n=df['MatchNumber']=='Final'
new=df[n]
new[['Season','WinningTeam']]
# Out:
#       Season            WinningTeam
# 0       2022         Gujarat Titans
# 74      2021    Chennai Super Kings
# 134  2020/21         Mumbai Indians
# 194     2019         Mumbai Indians
# 254     2018    Chennai Super Kings
# 314     2017         Mumbai Indians
# 373     2016    Sunrisers Hyderabad
# 433     2015         Mumbai Indians
# 492     2014  Kolkata Knight Riders
# 552     2013         Mumbai Indians
# 628     2012  Kolkata Knight Riders
# 702     2011    Chennai Super Kings
# 775  2009/10    Chennai Super Kings
# 835     2009        Deccan Chargers
# 892  2007/08       Rajasthan Royals

# %%
#player of match in final 

dff=df['MatchNumber']=='Final'
newd=df[dff]

newd[['Season','Player_of_Match']]
# Out:
#       Season Player_of_Match
# 0       2022       HH Pandya
# 74      2021    F du Plessis
# 134  2020/21        TA Boult
# 194     2019       JJ Bumrah
# 254     2018       SR Watson
# 314     2017       KH Pandya
# 373     2016     BCJ Cutting
# 433     2015       RG Sharma
# 492     2014       MK Pandey
# 552     2013      KA Pollard
# 628     2012        MS Bisla
# 702     2011         M Vijay
# 775  2009/10        SK Raina
# 835     2009        A Kumble
# 892  2007/08       YK Pathan

# %%
#which team won the most ipl trofee

n=df['MatchNumber']=='Final'
new=df[n]
new['WinningTeam'].value_counts()
# Out:
# Mumbai Indians           5
# Chennai Super Kings      4
# Kolkata Knight Riders    2
# Gujarat Titans           1
# Sunrisers Hyderabad      1
# Deccan Chargers          1
# Rajasthan Royals         1
# Name: WinningTeam, dtype: int64

# %%
n=df['MatchNumber']=='Final'
new=df[n]
new[['WinningTeam','Venue']]
# Out:
#                WinningTeam                                      Venue
# 0           Gujarat Titans           Narendra Modi Stadium, Ahmedabad
# 74     Chennai Super Kings        Dubai International Cricket Stadium
# 134         Mumbai Indians        Dubai International Cricket Stadium
# 194         Mumbai Indians         Rajiv Gandhi International Stadium
# 254    Chennai Super Kings                           Wankhede Stadium
# 314         Mumbai Indians  Rajiv Gandhi International Stadium, Uppal
# 373    Sunrisers Hyderabad                      M Chinnaswamy Stadium
# 433         Mumbai Indians                               Eden Gardens
# 492  Kolkata Knight Riders                      M Chinnaswamy Stadium
# 552         Mumbai Indians                               Eden Gardens
# 628  Kolkata Knight Riders            MA Chidambaram Stadium, Chepauk
# 702    Chennai Super Kings            MA Chidambaram Stadium, Chepauk
# ...

# %%
df['SuperOver'].value_counts()
# Out:
# N    932
# Y     14
# Name: SuperOver, dtype: int64

# %%
df['total_match']=df['Team1']+df['Team2']
df
# Out:
#           ID        City       Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  5/29/2022     2022        Final
# 1    1312199   Ahmedabad  5/27/2022     2022  Qualifier 2
# 2    1312198     Kolkata  5/25/2022     2022   Eliminator
# 3    1312197     Kolkata  5/24/2022     2022  Qualifier 1
# 4    1304116      Mumbai  5/22/2022     2022           70
# ..       ...         ...        ...      ...          ...
# 945   335986     Kolkata  4/20/2008  2007/08            4
# 946   335985      Mumbai  4/20/2008  2007/08            5
# 947   335984       Delhi  4/19/2008  2007/08            3
# 948   335983  Chandigarh  4/19/2008  2007/08            2
# 949   335982   Bangalore  4/18/2008  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
#total mach played by each team
(df['Team1'].value_counts() + df['Team2'].value_counts()).sort_values(ascending=False)
# Out:
# Mumbai Indians                 231
# Royal Challengers Bangalore    226
# Kolkata Knight Riders          223
# Chennai Super Kings            208
# Rajasthan Royals               192
# Kings XI Punjab                190
# Delhi Daredevils               161
# Sunrisers Hyderabad            152
# Deccan Chargers                 75
# Delhi Capitals                  63
# Pune Warriors                   46
# Gujarat Lions                   30
# Punjab Kings                    28
# Gujarat Titans                  16
# Rising Pune Supergiant          16
# Lucknow Super Giants            15
# Kochi Tuskers Kerala            14
# Rising Pune Supergiants         14
# dtype: int64

# %%
#toss decision 

df['TossDecision'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='TossDecision'>

# %%
#total super over
df[df['SuperOver']=='Y'].shape[0]
# Out:
# 14

# %%
#super over ratio
df["SuperOver"].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='SuperOver'>

# %%
df.head(2)
# Out:
#         ID       City       Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  5/29/2022   2022        Final
# 1  1312199  Ahmedabad  5/27/2022   2022  Qualifier 2
#
#                          Team1             Team2  \
# 0             Rajasthan Royals    Gujarat Titans
# 1  Royal Challengers Bangalore  Rajasthan Royals
#
#                               Venue        TossWinner TossDecision  ...  \
# 0  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals          bat  ...
# 1  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals        field  ...
#
#         WinningTeam    WonBy Margin  method Player_of_Match  \
# 0    Gujarat Titans  Wickets    7.0     NaN       HH Pandya
# 1  Rajasthan Royals  Wickets    7.0     NaN      JC Buttler
#
#                                         Team1Players  \
# 0  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
#
#                                         Team2Players      Umpire1  \
# ...

# %%
n=df['MatchNumber']=='Final'
new=df[n]
new[['WinningTeam','WonBy']]
# Out:
#                WinningTeam    WonBy
# 0           Gujarat Titans  Wickets
# 74     Chennai Super Kings     Runs
# 134         Mumbai Indians  Wickets
# 194         Mumbai Indians     Runs
# 254    Chennai Super Kings  Wickets
# 314         Mumbai Indians     Runs
# 373    Sunrisers Hyderabad     Runs
# 433         Mumbai Indians     Runs
# 492  Kolkata Knight Riders  Wickets
# 552         Mumbai Indians     Runs
# 628  Kolkata Knight Riders  Wickets
# 702    Chennai Super Kings     Runs
# 775    Chennai Super Kings     Runs
# 835        Deccan Chargers     Runs
# 892       Rajasthan Royals  Wickets

# %%
 # toss winner is match winner in percentage
(df[df['TossWinner'] == df['WinningTeam']].shape[0]/df.shape[0])*100
# Out:
# 51.473684210526315

# %%
#most ipl mtch played by city 

df['City'].value_counts()
# Out:
# Mumbai            159
# Kolkata            79
# Delhi              78
# Chennai            67
# Bangalore          65
# Hyderabad          64
# Chandigarh         56
# Pune               51
# Jaipur             47
# Abu Dhabi          37
# Ahmedabad          19
# Bengaluru          15
# Durban             15
# Visakhapatnam      13
# Dubai              13
# Centurion          12
# Rajkot             10
# Sharjah            10
# Dharamsala          9
# Navi Mumbai         9
# Indore              9
# Johannesburg        8
# Ranchi              7
# Cuttack             7
# Port Elizabeth      7
# Cape Town           7
# Raipur              6
# Kochi               5
# Kanpur              4
# Nagpur              3
# Kimberley           3
# East London         3
# Bloemfontein        2
# Name: City, dtype: int64

# %%
#player of the match 

df[df['MatchNumber'].str.isdigit()]['Player_of_Match'].value_counts()
# Out:
# AB de Villiers    23
# CH Gayle          21
# RG Sharma         17
# DA Warner         17
# MS Dhoni          16
#                   ..
# JO Holder          1
# Kartik Tyagi       1
# D Padikkal         1
# DJG Sammy          1
# MF Maharoof        1
# Name: Player_of_Match, Length: 256, dtype: int64
